# %%
import sys
from pathlib import Path
sys.path.append(Path(__file__).absolute().parent.parent)

# %%
from osTools.windowLayoutTools.desktops import Desktops
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Python311\lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\keilander\AppData\Local\Temp\ipykernel_21412\937326265.py", line 1, in <module>
#     from osTools.windowLayoutTools.desktops import Desktops
#   File "D:\python\osTools\windowLayoutTools\__init__.py", line 7, in <module>
#     from .windowLayout import * # noqa: F403,F401
#   File "D:\python\osTools\windowLayoutTools\windowLayout.py", line 305, in <module>
#     layout=WindowLayouts('sampleLayout.json')
#   File "D:\python\osTools\windowLayoutTools\windowLayout.py", line 189, in __init__
#     self.load(filename,apply)
#   File "D:\python\osTools\windowLayoutTools\windowLayout.py", line 286, in load
#     self.jsonStr=filename.read_text(encoding="utf-8",errors="ignore")
# ...

# %%
from osTools.windowLayoutTools.displays import Monitors

print(Monitors())
# Out:
# MONITOR\AUO23ED\{4d36e96e-e325-11ce-bfc1-08002be10318}\0002 (0,0,1920,1080)
# MONITOR\DEL41E3\{4d36e96e-e325-11ce-bfc1-08002be10318}\0003 (1920,0,1920,1080)

# %%
from osTools.windowLayoutTools import WindowLayouts

layouts=WindowLayouts('sampleLayout.json')
layouts.apply()
